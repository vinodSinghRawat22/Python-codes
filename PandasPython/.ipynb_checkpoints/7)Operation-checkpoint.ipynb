# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **DATA FRAMES BASIC OPERATIONS**

# %%
df = pd.DataFrame({
    'A': [10, 20, 30, 40, 50],
    'B': [5, 15, 25, 35, 45],
    'C': [2, 12, 22, 32, 42]
})
df
# Out:
#     A   B   C
# 0  10   5   2
# 1  20  15  12
# 2  30  25  22
# 3  40  35  32
# 4  50  45  42

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df.describe()
# Out:
#                A          B          C
# count   5.000000   5.000000   5.000000
# mean   30.000000  25.000000  22.000000
# std    15.811388  15.811388  15.811388
# min    10.000000   5.000000   2.000000
# 25%    20.000000  15.000000  12.000000
# 50%    30.000000  25.000000  22.000000
# 75%    40.000000  35.000000  32.000000
# max    50.000000  45.000000  42.000000

# %%
df['A']+10
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# Name: A, dtype: int64

# %% [markdown]
# **DATA FRAMES APPLYING FUNCTIONS**

# %%
df
# Out:
#     A   B   C
# 0  10   5   2
# 1  20  15  12
# 2  30  25  22
# 3  40  35  32
# 4  50  45  42

# %%
def square(x):
    return x**2

# %%
df['B'].apply(square) # to use a user defined function in dataframe column
# Out:
# 0        625
# 1      50625
# 2     390625
# 3    1500625
# 4    4100625
# Name: B, dtype: int64

# %%
df['B'] = df['B'].apply(square)  # to applly in Data frame

# %%
df
# Out:
#     A        B   C
# 0  10      625   2
# 1  20    50625  12
# 2  30   390625  22
# 3  40  1500625  32
# 4  50  4100625  42
